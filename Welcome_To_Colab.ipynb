# %% [markdown]
# <a href="https://colab.research.google.com/github/lithshyab/lithshyab/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid")
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn import preprocessing

# %%
data = pd.read_csv('/content/weatherHistory.csv')

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74045 entries, 0 to 74044
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            74045 non-null  object
#  1   Summary                   74044 non-null  object
#  2   Precip Type               73901 non-null  object
#  3   Temperature (C)           74044 non-null  float64
#  4   Apparent Temperature (C)  74044 non-null  float64
#  5   Humidity                  74044 non-null  float64
#  6   Wind Speed (km/h)         74044 non-null  float64
#  7   Wind Bearing (degrees)    74044 non-null  float64
#  8   Visibility (km)           74044 non-null  float64
#  9   Loud Cover                74044 non-null  float64
#  10  Pressure (millibars)      74044 non-null  float64
#  11  Daily Summary             74044 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 6.8+ MB

# %%
data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     74044.000000              74044.000000  74044.000000
# mean         11.699425                 10.577135      0.732572
# std           9.748904                 10.922002      0.196152
# min         -21.822222                -27.716667      0.000000
# 25%           4.005556                  1.844444      0.600000
# 50%          11.627778                 11.627778      0.780000
# 75%          18.816667                 18.816667      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       74044.000000            74044.000000     74044.000000     74044.0
# mean           10.873243              188.907447        10.068501         0.0
# std             6.996237              107.451866         3.978943         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
data.isnull().sum()
# Out:
# Summary                     0
# Precip Type                 0
# Temperature (C)             1
# Apparent Temperature (C)    1
# Humidity                    1
# Wind Speed (km/h)           1
# Wind Bearing (degrees)      1
# Visibility (km)             1
# Loud Cover                  1
# Pressure (millibars)        1
# Daily Summary               0
# dtype: int64

# %%
data.dropna()
# Out:
#        Summary  Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0           19            0         9.472222                  7.388889
# 1           19            0         9.355556                  7.227778
# 2           17            0         9.377778                  9.377778
# 3           19            0         8.288889                  5.944444
# 4           17            0         8.755556                  6.977778
# ...        ...          ...              ...                       ...
# 74039        6            0        11.850000                 11.850000
# 74040        6            0        11.088889                 11.088889
# 74041        6            0        11.066667                 11.066667
# 74042        6            0        10.161111                 10.161111
# 74043       19            0        13.711111                 13.711111
#
#        Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# ...

# %%
num = []

# %%
data.columns = data.columns.str.strip()
data.drop('Formatted Date', axis=1, inplace=True)

# %%
for col in data.columns:
  if data[col].dtype == 'object' :
    num.append(col)

# %%
num.remove('Formatted Date')
for col in num:
  print(f'{col} : {len(data[col].unique())}')
# Out:
# Summary : 27
# Precip Type : 3
# Daily Summary : 193

# %%
le = preprocessing.LabelEncoder()

# %%
for col in num:
  data[col] = le.fit_transform(data[col])
  print('classed found : ' , list(le.classes_))
# Out:
# classed found :  [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24), np.int64(25), np.int64(26)]
# classed found :  [np.int64(0), np.int64(1), np.int64(2)]
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(29)

# %%
data.drop_duplicates(inplace=True)

# %%
y=data['Temperature (C)']

# %%
x=data.drop(['Temperature (C)','Apparent Temperature (C)'],axis=1)
